# %% [markdown]
# <a href="https://colab.research.google.com/github/smartsw33t/TranslateML/blob/main/english_tamil_ui_mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-

"""
UI Vocabulary Sentence Generator & Annotator
Description: English to Tamil mapping for UI components with precise terminology.
Author: Jayaseelan Samuel
"""

# முழுமையான சொற்களஞ்சியம்
ui_vocab = {
    "Home": "முகப்பு", "Explore": "கண்டறிதல்", "Shorts": "குறும்படங்கள்",
    "Subscriptions": "சந்தாக்கள்", "Library": "களஞ்சியம்", "History": "வரலாறு",
    "Your videos": "உங்கள் காணொலிகள்", "Watch later": "பின்னர் பார்க்கலாம்",
    "Liked videos": "விரும்பிய காணொலிகள்", "Show more / Show less": "மேலும் காண்க/ குறைவாகக் காண்க",
    "Trending": "பேசுபொருளாகின்றன", "Music": "இசை", "Gaming": "விளையாட்டு",
    "Movies": "திரைப்படங்கள்", "News": "செய்திகள்", "Play / Pause": "இயக்குக/இடைநிறுத்துக",
    "Next / Previous": "அடுத்தது/முந்தினது", "Autoplay": "அதுவே இயக்கட்டும்",
    "Subtitles/Closed Captions": "எழுத்து வசனங்கள்/விரிவான எழுத்து வசனங்கள்",
    "Settings": "அமைப்புகள்", "Full screen": "முழுத்திரை", "Theater mode": "திரையரங்கப் பயன்முறை",
    "Miniplayer": "சிறுதிரை", "Mute / Unmute": "அமைதி/அமைதிநீக்குக", "Volume slider": "ஒலிக் கோடு",
    "Playback speed": "இயங்கும் வேகம்", "Quality": "தரம்", "Annotations": "விவரிப்புகள்",
    "Loop video": "முடிவில்லா காணொலி", "Seek bar": "தேடும் பட்டை", "Like / Dislike": "விருப்பு/வெறுப்பு",
    "Shares": "பகிர்தல்கள்", "Share": "பகிர்க", "Download": "பதிவிறக்குக", "Save": "சேமித்திடுக",
    "Subscribe / Subscribed": "சந்தாசேர்க/ சந்தாசேர்ந்தது", "Join": "இணைக", "Comment": "கருத்து",
    "Reply": "பதில்", "Sort by": "வரிசைப்படுத்துக", "Report": "புகார்செய்க",
    "Block user": "பயனரைத் தடுத்திடுக", "Notifications": "அறிவிப்புகள்", "Live chat": "நேரலை பேச்சு",
    "Super Chat / Super Thanks": "அருமையான பேச்சு / அருமையான நன்றி", "Clips": "படத்துண்டுகள்",
    "Channel dashboard": "வழிப்பாதையின் விவரப்பக்கம்", "Analytics": "பகுப்பாய்வுகள்",
    "Content": "பகிர்வு", "Playlists": "இயங்கு பட்டியல்கள்", "Community": "சமூகம்",
    "About": "அறிமுகம்", "Subscriber count": "சந்தாதாரர் எண்ணிக்கை", "Views": "பார்வைகள்",
    "Upload video": "காணொலியை ஏற்றுக", "Go live": "நேரலை செல்க", "Create a post": "ஒரு பதிவை உருவாக்குக",
    "Channel trailer": "வழிப்பாதையின் முன்னோட்டம்", "End screen": "முடிவுத்திரை", "Cards": "அட்டைகள்",
    "Custom URL / Handle": "விருப்பப்படியான பிணைப்பு/ கைப்பிடி", "Account": "கணக்கு",
    "Switch account": "கணக்கை மாற்றுக", "Sign out": "வெளியேறுக",
    "Dark theme / Light theme": "கருநிற பின்னணி/ வெளிர் பின்னணி", "Language": "மொழி",
    "Location": "இடம்", "Restricted Mode": "கட்டுப்படுத்தப்பட்ட பயன்முறை",
    "Privacy policy": "அந்தரங்கக் கொள்கை", "Terms of Service": "சேவை விதிமுறைகள்",
    "Help & Feedback": "உதவியும் அனுபவத்தில் சொல்தலும்", "Manage Google Account": "கூகுள் கணக்கை ஆளுமைசெய்க",
    "Purchases and memberships": "வாங்குதல்களும் சந்தாக்களும்", "Your data in UI": "UI-இல் உங்கள் தகவல்கள்",
    "Connected apps": "இணைக்கப்பட்ட செயலிகள்", "Billing & payments": "விலைச்சீட்டும் கட்டணங்களும்",
    "Search bar": "தேடல் பட்டை", "Search filters": "தேடல் வடிகட்டிகள்", "Upload date": "பதிவேற்றிய தேதி",
    "Type": "வகை", "Duration": "கால அளவு", "Features": "அம்சங்கள்",
    "Clear search history": "தேடல் வரலாற்றை நீக்குக", "Voice search": "குரல் தேடல்",
    "Recommended for you": "உங்களுக்கான பரிந்துரை", "Related videos": "தொடர்புடைய காணொலிகள்",
    "Visibility (Public, Private, Unlisted)": "தெரியும் விதம் (பொது, தனிப்பட்டது, பட்டியலிடப்படாதது)",
    "Monetization": "வருமானம் பெறுதல்", "Copyright claim / strike": "காப்புரிமைக் கோரல்/ தடைவிதித்தல்",
    "Audience (Made for kids / Not made for kids)": "பார்க்கவேண்டியவர்கள்(சிறுவருக்கானது/சிறுவருக்கு அல்லாதது)",
    "Tags": "விவரப்பட்டைகள்", "Category": "பிரிவு", "Thumbnail": "சிறு படம்",
    "Description": "விளக்கம்", "Video title": "காணொலி தலைப்பு", "Comments and ratings": "கருத்துகளும் மதிப்பீடுகளும்",
    "Permissions": "அனுமதிகள்", "Audio library": "ஒலிக் களஞ்சியம்", "Customization": "விருப்பப்படி ஆக்குதல்",
    "Branding": "சின்னமாக்குதல்", "Basic info": "அடிப்படைத் தகவல்", "AI Prompt": "செ.நு கேட்டல்",
    "Prompt": "கேட்டல்", "Carousel": "உருளும் படங்கள்", "Give Feedback": "அனுபவத்தில் சொல்க",
    "Presentation": "காட்சிப்படுத்தி வழங்கல்", "Proposal": "முன்மொழிதல்", "News Feed": "பதிவுகள் ஓடை",
    "Feed": "ஓடை", "Reels": "சுருள்கள்", "Reel": "சுருள்", "Message": "குறுஞ்செய்தி",
    "Chat": "பேச்சு", "Chatbot": "பேச்சுப்பொறி", "Feedback": "அனுபவத்தில் சொல்லுதல்",
    "Audio": "ஒலி", "Recording": "பதிவுசெய்தல்", "Placeholder": "நிரப்பப்படுமிடம்",
    "Link": "பிணைப்பு", "Connection": "இணைப்பு", "Attachment": "சேர்ப்பு"
}

def generate_annotated_sentences():
    print(f"{'No.':<4} | {'UI Component':<40} | {'Tamil Meaning'}")
    print("=" * 115)

    for i, (english, tamil) in enumerate(ui_vocab.items(), 1):
        # UI சார்ந்த முறையான வாக்கிய அமைப்பு
        example_en = f"Select the {english} feature."
        example_ta = f"{tamil} என்ற விருப்பத்தேர்வை தேர்ந்தெடுக்கவும்."

        print(f"{i:<4} | {english:<40} | {tamil}")
        print(f"     [ENG] {example_en}")
        print(f"     [TAM] {example_ta}\n")

if __name__ == "__main__":
    # தமிழ் எழுத்துக்கள் சரியாகத் தெரிய UTF-8 உறுதி செய்யப்படுகிறது
    generate_annotated_sentences()
# Out:
# No.  | UI Component                             | Tamil Meaning
# ...
# 1    | Home                                     | முகப்பு
#      [ENG] Select the Home feature.
#      [TAM] முகப்பு என்ற விருப்பத்தேர்வை தேர்ந்தெடுக்கவும்.
#
# 2    | Explore                                  | கண்டறிதல்
#      [ENG] Select the Explore feature.
#      [TAM] கண்டறிதல் என்ற விருப்பத்தேர்வை தேர்ந்தெடுக்கவும்.
#
# 3    | Shorts                                   | குறும்படங்கள்
#      [ENG] Select the Shorts feature.
#      [TAM] குறும்படங்கள் என்ற விருப்பத்தேர்வை தேர்ந்தெடுக்கவும்.
#
# 4    | Subscriptions                            | சந்தாக்கள்
#      [ENG] Select the Subscriptions feature.
#      [TAM] சந்தாக்கள் என்ற விருப்பத்தேர்வை தேர்ந்தெடுக்கவும்.
#
# 5    | Library                                  | களஞ்சியம்
#      [ENG] Select the Library feature.
#      [TAM] களஞ்சியம் என்ற விருப்பத்தேர்வை தேர்ந்தெடுக்கவும்.
#
# 6    | History                                  | வரலாறு
# ...
